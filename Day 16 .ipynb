# %%
import pandas as pd

# %%
df =  pd.read_csv('datasets/khp-data.csv')

# %%
df.head()
# Out:
#               NAME      Stream Shift Subject Combination  Shift.1  \
# 0  Prasanna Paudel  Management   NaN                 NaN  Morning
# 1  KUSHAN PYAKUREL  Management   NaN                 NaN  Morning
# 2     RITIMA DULAL  Management   NaN                 NaN  Morning
# 3    Laxmi Gajurel  Management   NaN                 NaN  Morning
# 4  Pranisha Sanjel  Management   NaN                 NaN  Morning
#
#                     Subject Combination.1 Subject Combination.2  \
# 0  Computer Science, Business Mathematics                   NaN
# 1  Computer Science, Business Mathematics                   NaN
# 2             Business Studies, Economics                   NaN
# 3      Business Studies, Hotel Management                   NaN
# 4  Computer Science, Business Mathematics                   NaN
#
#   Subject Combination.3 Subject Combination.4 SEE Final Grade [E. English]  \
# 0                   NaN                   NaN                           A+
# ...
