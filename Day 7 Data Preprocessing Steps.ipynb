# %% [markdown]
# # 1. Data Understanding

# %%
import pandas as pd 
from seaborn import load_dataset

# %%
# load dataset 
data = load_dataset('titanic')

# %%
# Get basic information about dataset 
print("data set info:")
print(data.info()) 
#datatypes,missing values ,etc
# Out:
# data set info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %%
# Display summary statics for numerical columns 
print("\n Summary statics")
print(data.describe())
# Out:
#  Summary statics
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Display the first few rows of the dataset 
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 2. Data Cleaning

# %%
# check for missing values in dataset 
missing_values = data.isnull().sum()
print("Missing values in Each Column:")
print(missing_values[missing_values > 0])
# Out:
# Missing values in Each Column:
# age            177
# embarked         2
# deck           688
# embark_town      2
# dtype: int64

# %%
# Impute missing values un 'age' with the median 
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
data['age'] = imputer.fit_transform(data[['age']])

# Drops rows where 'embarked' has missing values 
data.dropna(subset=['embarked'],inplace=True)
data.dropna(subset=['deck'],inplace=True)



# verify that missing values are handled 
print("Missing values after imputaion ")
print(data.isnull().sum())
# Out:
# Missing values after imputaion
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
#  Removing Duplicates
#remove duplicate rows 
before = data.shape[0]
data = data.drop_duplicates()
after = data.shape[0]
print(f"Removed {before-after} duplicate rows")
# Out:
# Removed 0 duplicate rows

# %%
# Outlier Detection and Treatment (using IQR method)
# Deteact outlier using the IQR method for the age column 
Q1 = data['age'].quantile(0.25)
Q3 = data['age'].quantile(0.75)
IQR = Q3 - Q1

# Filter oout outliers 
outliers = data[(data['age']< (Q1 - 1.5 *IQR)) | data['age'] > (Q3 + 1.5*IQR)]
print(f"Number of Outlier detected, {len(outliers)} ")

# IQR (INTER QUARTLE RANGE ) - Measures the spread of the middle 50% of data.
# Out:
# Number of Outlier detected, 0

# %% [markdown]
# # 3.data Transformation

# %%
# 1. Scaling and noamalization

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler, RobustScaler 

# Min-Max Scaling for 'age'
min_max_scaler = MinMaxScaler()
data['age_scaled'] = min_max_scaler.fit_transform(data[['age']])

# %%
# Standarization of fare 
standard_scaler = StandardScaler()
data['fare_standarized'] = standard_scaler.fit_transform(data[['fare']])

# %%
# Robust Scaling to reduce the effect of outliers on 'fare'
robust_scaler = RobustScaler()
data['fare_robust'] = robust_scaler.fit_transform(data[['fare']])

# %%
# 2. Encoding categorical data

# %%
# Label Encoding
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
LE = LabelEncoder()
data['sex_encoded'] = LE.fit_transform(data['sex']) # Turns male into 1 and Female :0

# %%
# One Hot Encoding
embarked_dummies = pd.get_dummies(data['embarked'],prefix='embarked')
data = pd.concat([data,embarked_dummies],axis=1)
# Display the data 
print(data[['sex','sex_encoded','embarked_C','embarked_Q','embarked_S']].head())
# Out:
#        sex  sex_encoded  embarked_C  embarked_C  embarked_Q  embarked_Q  \
# 1   female            0        True        True       False       False
# 3   female            0       False       False       False       False
# 6     male            1       False       False       False       False
# 10  female            0       False       False       False       False
# 11  female            0       False       False       False       False
#
#     embarked_S  embarked_S
# 1        False       False
# 3         True        True
# 6         True        True
# 10        True        True
# 11        True        True

# %%
# 3. feature Transformation

# %%
from sklearn.preprocessing import FunctionTransformer

# Log tranform on 'fare' to reduce skewnesss
log_transformer = FunctionTransformer(np.log1p,validate=True)


# left

# %% [markdown]
# # 4. Feature Engineering

# %%
# 1.create a new feature 
data['family_size'] = data['sibsp'] + data['parch'] + 1 

print(data[['sibsp','parch','family_size']].head())
# Out:
#     sibsp  parch  family_size
# 1       1      0            2
# 3       1      0            2
# 6       0      0            1
# 10      1      1            3
# 11      0      0            1

# %%
# 2.Extracting features from text
data['title'] = data['name'].str.extract('([A-Za-z]+)\\.',expand=False)


# count teh occurecnce of each title
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 2
#       1 # 2.Extracting features from text
# ----> 2 data['title'] = data['name'].str.extract('([A-Za-z]+)\\.',expand=False)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  ... embarked_C  embarked_Q  embarked_S embarked_C  embarked_Q  \
# 1    woman  ...       True       False       False       True       False
# 3    woman  ...      False       False        True      False       False
# 6      man  ...      False       False        True      False       False
# 10   child  ...      False       False        True      False       False
# 11   woman  ...      False       False        True      False       False
# ..     ...  ...        ...         ...         ...        ...         ...
# 871  woman  ...      False       False        True      False       False
# 872    man  ...      False       False        True      False       False
# 879  woman  ...       True       False       False       True       False
# 887  woman  ...      False       False        True      False       False
# 889    man  ...       True       False       False       True       False
#
#      embarked_S  fare_log  age_reciprocal  age_sqrt  family_size
# 1         False  4.280593        0.026316  6.164414            2
# 3          True  3.990834        0.028571  5.916080            2
# 6          True  3.967694        0.018519  7.348469            1
# 10         True  2.873565        0.249999  2.000000            3
# 11         True  3.316003        0.017241  7.615773            1
# ..          ...       ...             ...       ...          ...
# 871        True  3.980694        0.021277  6.855655            3
# 872        True  1.791759        0.030303  5.744563            1
# 879       False  4.432700        0.017857  7.483315            2
# 887        True  3.433987        0.052632  4.358899            1
# 889       False  3.433987        0.038462  5.099020            1
#
# [200 rows x 29 columns]
